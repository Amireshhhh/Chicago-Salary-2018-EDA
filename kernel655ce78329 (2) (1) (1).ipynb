# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/2018-chicago-employees-salaries/chicago_employees.csv

# %%
df=pd.read_csv('/kaggle/input/2018-chicago-employees-salaries/chicago_employees.csv')

# %% [markdown]
# We begin by explorung the data and see something interesting

# %%
df.head()
# Out:
#                   Name                              Job Titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#   Annual Salary Hourly Rate
# 0    $101442.00         NaN
# 1     $94122.00         NaN
# 2    $101592.00         NaN
# 3    $110064.00         NaN
# 4           NaN      $19.86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33183 entries, 0 to 33182
# Data columns (total 8 columns):
# Name                 33183 non-null object
# Job Titles           33183 non-null object
# Department           33183 non-null object
# Full or Part-Time    33183 non-null object
# Salary or Hourly     33183 non-null object
# Typical Hours        8022 non-null float64
# Annual Salary        25161 non-null object
# Hourly Rate          8022 non-null object
# dtypes: float64(1), object(7)
# memory usage: 2.0+ MB

# %%
df.count()
# Out:
# Name                 33183
# Job Titles           33183
# Department           33183
# Full or Part-Time    33183
# Salary or Hourly     33183
# Typical Hours         8022
# Annual Salary        25161
# Hourly Rate           8022
# dtype: int64

# %% [markdown]
# We see that the column "Hourly Rate" has too many null values, and it's obvious that this variable is correlated with a linear function to annual salary, which is the part that we want to see details and relations about it. so we gonna remove this column anyway.

# %%
df.drop('Hourly Rate',axis=1, inplace=True)

# %% [markdown]
# Now let's see the some descriptive statistics about annual salary

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# So we need to convert this attribute to integers.

# %% [markdown]
# Feature engineering

# %% [markdown]
# We first replace the $ sign from the each row that has the number and ve omit the .00 value of the cents( With respect to the median that we will see in the following, cents are neglectable in this model)

# %%
for i in range(df["Annual Salary"].size):
    if(type(df["Annual Salary"][i])==str):
            df["Annual Salary"][i]=df["Annual Salary"][i].replace("$","")
            df["Annual Salary"][i]=df["Annual Salary"][i].replace(".00","")
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df["Annual Salary"]
# Out:
# 0        101442
# 1         94122
# 2        101592
# 3        110064
# 4           NaN
#           ...
# 33178     72510
# 33179     48078
# 33180     90024
# 33181     93354
# 33182    115932
# Name: Annual Salary, Length: 33183, dtype: object

# %%
for i in range(df["Annual Salary"].size):
    if(type(df["Annual Salary"][i])==str):
        if(not df["Annual Salary"][i]==False):
            df["Annual Salary"][i]=float(df["Annual Salary"][i])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# We see that some values have other cents amount.

# %%
df["Annual Salary"].plot().hist
# Out:
# <bound method Axes.hist of <matplotlib.axes._subplots.AxesSubplot object at 0x7f513fd628d0>>

# %% [markdown]
# Now we replace the missing values for Annual Salary column with the median of the sample, and then we're gonna replace it with mean sample and see the differences.

# %%
median=df["Annual Salary"].median()
value1={"Annual Salary": median}
df.fillna(value=value1)
# Out:
#                         Name                              Job Titles  \
# 0          AARON,  JEFFERY M                                SERGEANT
# 1            AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2        AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4          ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
# ...                      ...                                     ...
# 33178  ZYLINSKA,  KATARZYNA                           POLICE OFFICER
# 33179     ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33180      ZYMANTAS,  MARK E                          POLICE OFFICER
# 33181    ZYRKOWSKI,  CARLO E                          POLICE OFFICER
# 33182   ZYSKOWSKI,  DARIUSZ                  CHIEF DATA BASE ANALYST
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0                POLICE                 F           Salary            NaN
# 1                POLICE                 F           Salary            NaN
# 2      GENERAL SERVICES                 F           Salary            NaN
# 3           WATER MGMNT                 F           Salary            NaN
# 4                  OEMC                 P           Hourly           20.0
# ...                 ...               ...              ...            ...
# 33178            POLICE                 F           Salary            NaN
# 33179            POLICE                 F           Salary            NaN
# 33180            POLICE                 F           Salary            NaN
# 33181            POLICE                 F           Salary            NaN
# 33182              DoIT                 F           Salary            NaN
#
#        Annual Salary
# 0           101442.0
# 1            94122.0
# 2           101592.0
# 3           110064.0
# 4            90024.0
# ...              ...
# 33178        72510.0
# 33179        48078.0
# 33180        90024.0
# 33181        93354.0
# 33182       115932.0
#
# [33183 rows x 7 columns]

# %% [markdown]
# Now we are done with this column and and we need to check the typical hour column

# %%
df["Typical Hours"].value_counts()
# Out:
# 40.0    5833
# 20.0    1901
# 10.0     184
# 35.0     104
# Name: Typical Hours, dtype: int64

# %% [markdown]
# As we see, only near 8000 rows have non-null values and the 25% of the population has 20 hours for this column, we will need to do something about this problem, but first let make another data frame without this column and do some analysis

# %%
df1= df.drop("Typical Hours", axis=1, inplace=False)

# %%
df["Full or Part-Time"].value_counts()
# Out:
# F    31090
# P     2093
# Name: Full or Part-Time, dtype: int64

# %% [markdown]
# So by this we can manage the Typical Hours Salary, since if someone is emplpyed as a full time position, they will have to work 40 hours per week.

# %% [markdown]
# Lets see what we can find from job titles column

# %%
df["Job Titles"].describe()
# Out:
# count              33183
# unique              1111
# top       POLICE OFFICER
# freq                9520
# Name: Job Titles, dtype: object

# %% [markdown]
# we see that we have 1111 unique values into the 33183 samples and Police Officer is the most job used with 9520 times used. So with having this in mind, spilit the dataset by jobs may sound interesting, lets see what we can get about pollice officers.

# %%
police=df[df["Job Titles"]=="POLICE OFFICER"]

# %%
police
# Out:
#                          Name      Job Titles Department Full or Part-Time  \
# 9            ABBATE,  TERRY M  POLICE OFFICER     POLICE                 F
# 11           ABDALLAH,  ZAID   POLICE OFFICER     POLICE                 F
# 12     ABDELHADI,  ABDALMAHD   POLICE OFFICER     POLICE                 F
# 14        ABDELMAJEID,  AZIZ   POLICE OFFICER     POLICE                 F
# 22          ABEJERO,  JASON V  POLICE OFFICER     POLICE                 F
# ...                       ...             ...        ...               ...
# 33177        ZYGMUNT,  DAWID   POLICE OFFICER     POLICE                 F
# 33178   ZYLINSKA,  KATARZYNA   POLICE OFFICER     POLICE                 F
# 33179      ZYMANTAS,  LAURA C  POLICE OFFICER     POLICE                 F
# 33180       ZYMANTAS,  MARK E  POLICE OFFICER     POLICE                 F
# 33181     ZYRKOWSKI,  CARLO E  POLICE OFFICER     POLICE                 F
#
#       Salary or Hourly  Typical Hours Annual Salary
# 9               Salary            NaN         93354
# 11              Salary            NaN         84054
# 12              Salary            NaN         87006
# 14              Salary            NaN         84054
# 22              Salary            NaN         90024
# ...                ...            ...           ...
# 33177           Salary            NaN         72510
# 33178           Salary            NaN         72510
# 33179           Salary            NaN         48078
# 33180           Salary            NaN         90024
# 33181           Salary            NaN         93354
#
# [9520 rows x 7 columns]

# %% [markdown]
# Lets see the distributions

# %%
police["Annual Salary"].describe()
# Out:
# count      9520.0
# unique       15.0
# top       90024.0
# freq       2065.0
# Name: Annual Salary, dtype: float64

# %%
police["Annual Salary"].mean()
# Out:
# 82149.49600840337

# %%
police["Annual Salary"].std()
# Out:
# 14204.522343967055

# %% [markdown]
# Now lets fit a kernel density function to the distribution of policemen salaries:

# %%
police["Annual Salary"].plot.kde()

# %% [markdown]
# from this plot the first guess is that the group of policemen can be devided in two general part like part A and part B which part A represents the left peak and part B represent the right peak.
# The very first other guess is that the part A is the entry level ones with less experience while the group B is the ones with higher experience

# %% [markdown]
# now lets see what other titles can say more

# %%
#df=df[df["Job Titles"]!="POLICE OFFICER"]

# %%
df
# Out:
#                         Name                              Job Titles  \
# 0          AARON,  JEFFERY M                                SERGEANT
# 1            AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2        AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4          ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
# ...                      ...                                     ...
# 33178  ZYLINSKA,  KATARZYNA                           POLICE OFFICER
# 33179     ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33180      ZYMANTAS,  MARK E                          POLICE OFFICER
# 33181    ZYRKOWSKI,  CARLO E                          POLICE OFFICER
# 33182   ZYSKOWSKI,  DARIUSZ                  CHIEF DATA BASE ANALYST
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0                POLICE                 F           Salary            NaN
# 1                POLICE                 F           Salary            NaN
# 2      GENERAL SERVICES                 F           Salary            NaN
# 3           WATER MGMNT                 F           Salary            NaN
# 4                  OEMC                 P           Hourly           20.0
# ...                 ...               ...              ...            ...
# 33178            POLICE                 F           Salary            NaN
# 33179            POLICE                 F           Salary            NaN
# 33180            POLICE                 F           Salary            NaN
# 33181            POLICE                 F           Salary            NaN
# 33182              DoIT                 F           Salary            NaN
#
#       Annual Salary
# 0            101442
# 1             94122
# 2            101592
# 3            110064
# 4               NaN
# ...             ...
# 33178         72510
# 33179         48078
# 33180         90024
# 33181         93354
# 33182        115932
#
# [33183 rows x 7 columns]

# %%
df["Annual Salary"].plot.kde()

# %% [markdown]
# Now it's more reasonable since data now has more normal distribution, now lets see the outliers

# %%
out1=df[df["Annual Salary"]>180000]
out2=df[df["Annual Salary"]<30000]

# %%
out1
# Out:
#                         Name                      Job Titles      Department  \
# 6739          DEAL,  AARON J                  CHIEF OF STAFF  MAYOR'S OFFICE
# 8036   EDGEWORTH,  RICHARD A        DEPUTY FIRE COMMISSIONER            FIRE
# 8195         EMANUEL,  RAHM                            MAYOR  MAYOR'S OFFICE
# 8436        EVANS,  GINGER S        COMMISSIONER OF AVIATION        AVIATION
# 9224     FORD II,  RICHARD C  FIRST DEPUTY FIRE COMMISSIONER            FIRE
# 13223        HROMA,  DONALD         DEPUTY FIRE COMMISSIONER            FIRE
# 14216      JOHNSON,  EDDIE T        SUPERINTENDENT OF POLICE          POLICE
# 16717     LEWIN,  JONATHAN H                           CHIEF          POLICE
# 20973      NAVARRO,  KEVIN B     FIRST DEPUTY SUPERINTENDENT          POLICE
# 24631     RICCIO,  ANTHONY J                           CHIEF          POLICE
# 24939      RIVKIN,  ROBERT S        ADMINISTRATIVE SECRETARY  MAYOR'S OFFICE
# 26190     SAMPEY,  TIMOTHY T   ASST DEPUTY FIRE COMMISSIONER            FIRE
# 26419      SANTIAGO,  JOSE A               FIRE COMMISSIONER            FIRE
# 27163      SHERIDAN,  MARY L   ASST DEPUTY FIRE COMMISSIONER            FIRE
# 28323    STAPLES,  MELISSA A                           CHIEF          POLICE
# 30504    VASQUEZ,  ANTHONY P        DEPUTY FIRE COMMISSIONER            FIRE
# 30904       VOGT,  WILLIAM C        DEPUTY FIRE COMMISSIONER            FIRE
# 31100        WALLER,  FRED L                           CHIEF          POLICE
# 31540    WELCH III,  EDDIE L                           CHIEF          POLICE
# 31595       WEST,  BARBARA J                           CHIEF          POLICE
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary
# 6739                  F           Salary            NaN        195000
# 8036                  F           Salary            NaN        187680
# 8195                  F           Salary            NaN        216210
# 8436                  F           Salary            NaN        300000
# 9224                  F           Salary            NaN        197736
# 13223                 F           Salary            NaN        187680
# 14216                 F           Salary            NaN        260004
# 16717                 F           Salary            NaN        185364
# 20973                 F           Salary            NaN        197724
# 24631                 F           Salary            NaN        185364
# 24939                 F           Salary            NaN        185004
# 26190                 F           Salary            NaN        185352
# 26419                 F           Salary            NaN        202728
# 27163                 F           Salary            NaN        185352
# 28323                 F           Salary            NaN        185364
# 30504                 F           Salary            NaN        187680
# 30904                 F           Salary            NaN        187680
# 31100                 F           Salary            NaN        185364
# 31540                 F           Salary            NaN        185364
# 31595                 F           Salary            NaN        185364

# %%
out2
# Out:
#                             Name                          Job Titles  \
# 178            ADELMAN,  BRUCE E                    LEGISLATIVE AIDE
# 373         ALEGRIA,  CRISTINA G             CLERK - BD OF ELECTIONS
# 970          ARENAS,  ANA LUISA                        LIBRARY CLERK
# 1374           BAKER JR,  RALPH              CLERK - BD OF ELECTIONS
# 1395      BALASKOVITS,  KATHRYN                   CLERK CITY COUNCIL
# 1741          BATTLE,  ANTHONY C  ELECTION EQUIPMENT & SUPPLY SPEC I
# 1884           BEHLING,  DAVID M             CLERK - BD OF ELECTIONS
# 2074         BERONSKI,  BARBARA                     LEGISLATIVE AIDE
# 2383       BLONSKI,  KATHERINE E                     ALDERMANIC AIDE
# 2693   BOYD-GREATHOUSE,  KAREN D             CLERK - BD OF ELECTIONS
# 3250            BROWN,  RACHEL J             CLERK - BD OF ELECTIONS
# 3532          BURKS,  BRITTANY S                     ALDERMANIC AIDE
# 4065            CARDENAS,  JOSE                        LIBRARY CLERK
# 4393         CASPER,  NICHOLAS S             CLERK - BD OF ELECTIONS
# 4574            CEREZO,  ANGELA              CLERK - BD OF ELECTIONS
# 6113              CRUZ,  ALYSE M                  CLERK CITY COUNCIL
# 6471          DANIEL,  STANLEY J                    LEGISLATIVE AIDE
# 6513            DATRO,  BLANCA E                       LIBRARY CLERK
# 6566          DAVILA,  ROBERTO A          STAFF ASST TO THE ALDERMAN
# 6588             DAVIS,  CHERYL              CLERK - BD OF ELECTIONS
# 6669          DAVIS,  PATRICIA A                     ALDERMANIC AIDE
# 6870        DE LA TORRE,  JOSE L                    LEGISLATIVE AIDE
# 6906          DELGADO,  CECILIA                   CLERK CITY COUNCIL
# 7805           DUKES,  DOROTHY L                     ALDERMANIC AIDE
# 7892         DURHAM,  JENNIFER M             CLERK - BD OF ELECTIONS
# 8814     FIGUEROA,  ALEXANDRIA C                    LEGISLATIVE AIDE
# 9018          FLETCHER,  BETTY A                    LEGISLATIVE AIDE
# 9038           FLOOD,  CHARLES P                    LEGISLATIVE AIDE
# 9580          GABINSKI,  MOLLY C                    LEGISLATIVE AIDE
# 9927             GARCIA,  MARIO              CLERK - BD OF ELECTIONS
# 10018          GARNER,  SANDRA Y             CLERK - BD OF ELECTIONS
# 12893           HOGAN,  BRYANT R             CLERK - BD OF ELECTIONS
# 13300           HUGHES,  COLIN K                  CLERK CITY COUNCIL
# 13729         JACKSON JR,  FRED           STAFF ASST TO THE ALDERMAN
# 16028        KUSCHELL,  ROBERT A                       LIBRARY CLERK
# 16870             LIN,  ANTHONY              CLERK - BD OF ELECTIONS
# 17867        MANION,  MARYKATE D                    LEGISLATIVE AIDE
# 18106         MARTINEZ,  ALICIA                   CLERK CITY COUNCIL
# 18212        MARTINEZ,  ROBERTO                   CLERK CITY COUNCIL
# 18263           MARTIN,  LEONA T             CLERK - BD OF ELECTIONS
# 21695           O GARA,  ELLEN M                    LEGISLATIVE AIDE
# 24104        RAMIREZ,  VERONICA                     LEGISLATIVE AIDE
# 25022        ROBERTS,  PATRICK N                    LEGISLATIVE AIDE
# 29202            TAYLOR,  INES W                     ALDERMANIC AIDE
# 29310   TERRELL HART,  ADRIENNE                      ALDERMANIC AIDE
# 29684        TOLLINCHI,  JUDITH              CLERK - BD OF ELECTIONS
# 30155             TURPIN,  RENA   ELECTION EQUIPMENT & SUPPLY SPEC I
# 30256         URQUHART,  PIERRE                        LIBRARY CLERK
# 32580             WORD,  BRYCE D                    LEGISLATIVE AIDE
# 32725            YANCY,  ETHEL M                    LEGISLATIVE AIDE
# 32875            ZABEL,  SHERRY              CLERK - BD OF ELECTIONS
#
#               Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 178         CITY COUNCIL                 F           Salary            NaN
# 373    BOARD OF ELECTION                 F           Salary            NaN
# 970       PUBLIC LIBRARY                 F           Salary            NaN
# 1374   BOARD OF ELECTION                 F           Salary            NaN
# 1395        CITY COUNCIL                 F           Salary            NaN
# 1741   BOARD OF ELECTION                 F           Salary            NaN
# 1884   BOARD OF ELECTION                 F           Salary            NaN
# 2074        CITY COUNCIL                 F           Salary            NaN
# 2383        CITY COUNCIL                 P           Salary            NaN
# 2693   BOARD OF ELECTION                 F           Salary            NaN
# 3250   BOARD OF ELECTION                 F           Salary            NaN
# 3532        CITY COUNCIL                 F           Salary            NaN
# 4065      PUBLIC LIBRARY                 F           Salary            NaN
# 4393   BOARD OF ELECTION                 F           Salary            NaN
# 4574   BOARD OF ELECTION                 F           Salary            NaN
# 6113        CITY COUNCIL                 F           Salary            NaN
# 6471        CITY COUNCIL                 F           Salary            NaN
# 6513      PUBLIC LIBRARY                 F           Salary            NaN
# 6566        CITY COUNCIL                 F           Salary            NaN
# 6588   BOARD OF ELECTION                 F           Salary            NaN
# 6669        CITY COUNCIL                 P           Salary            NaN
# 6870        CITY COUNCIL                 F           Salary            NaN
# 6906        CITY COUNCIL                 F           Salary            NaN
# 7805        CITY COUNCIL                 F           Salary            NaN
# 7892   BOARD OF ELECTION                 F           Salary            NaN
# 8814        CITY COUNCIL                 F           Salary            NaN
# 9018        CITY COUNCIL                 F           Salary            NaN
# 9038        CITY COUNCIL                 F           Salary            NaN
# 9580        CITY COUNCIL                 F           Salary            NaN
# 9927   BOARD OF ELECTION                 F           Salary            NaN
# 10018  BOARD OF ELECTION                 F           Salary            NaN
# 12893  BOARD OF ELECTION                 F           Salary            NaN
# 13300       CITY COUNCIL                 F           Salary            NaN
# 13729       CITY COUNCIL                 F           Salary            NaN
# 16028     PUBLIC LIBRARY                 F           Salary            NaN
# 16870  BOARD OF ELECTION                 F           Salary            NaN
# 17867       CITY COUNCIL                 F           Salary            NaN
# 18106       CITY COUNCIL                 F           Salary            NaN
# 18212       CITY COUNCIL                 F           Salary            NaN
# 18263  BOARD OF ELECTION                 F           Salary            NaN
# 21695       CITY COUNCIL                 F           Salary            NaN
# 24104       CITY COUNCIL                 F           Salary            NaN
# 25022       CITY COUNCIL                 F           Salary            NaN
# 29202       CITY COUNCIL                 F           Salary            NaN
# 29310       CITY COUNCIL                 F           Salary            NaN
# 29684  BOARD OF ELECTION                 F           Salary            NaN
# 30155  BOARD OF ELECTION                 F           Salary            NaN
# 30256     PUBLIC LIBRARY                 F           Salary            NaN
# 32580       CITY COUNCIL                 F           Salary            NaN
# 32725       CITY COUNCIL                 F           Salary            NaN
# 32875  BOARD OF ELECTION                 F           Salary            NaN
#
#       Annual Salary
# 178           19968
# 373           29328
# 970           29064
# 1374          29328
# 1395          25008
# 1741          27912
# 1884          28608
# 2074          21672
# 2383           7200
# 2693          27912
# 3250          29328
# 3532          15012
# 4065          29064
# 4393          28608
# 4574          29328
# 6113          23424
# 6471          25092
# 6513          29064
# 6566          29004
# 6588          28608
# 6669          13800
# 6870          25200
# 6906          23196
# 7805          15000
# 7892          28608
# 8814          25200
# 9018          24996
# 9038          25200
# 9580          25200
# 9927          28608
# 10018         29328
# 12893         28608
# 13300         21948
# 13729         24996
# 16028         29064
# 16870         28608
# 17867         25452
# 18106         23196
# 18212         28452
# 18263         29328
# 21695         21108
# 24104         26628
# 25022         25200
# 29202         15000
# 29310         12840
# 29684         29328
# 30155         27912
# 30256         29064
# 32580         25008
# 32725         25980
# 32875         28608

# %% [markdown]
# This two list can say what are the best jobs and worst jobs in chicago according to this dataset.

# %%
x=df[df["Department"]=="POLICE"]

# %%
x
# Out:
#                          Name                              Job Titles  \
# 0           AARON,  JEFFERY M                                SERGEANT
# 1             AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 9            ABBATE,  TERRY M                          POLICE OFFICER
# 11           ABDALLAH,  ZAID                           POLICE OFFICER
# 12     ABDELHADI,  ABDALMAHD                           POLICE OFFICER
# ...                       ...                                     ...
# 33177        ZYGMUNT,  DAWID                           POLICE OFFICER
# 33178   ZYLINSKA,  KATARZYNA                           POLICE OFFICER
# 33179      ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33180       ZYMANTAS,  MARK E                          POLICE OFFICER
# 33181     ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0         POLICE                 F           Salary            NaN
# 1         POLICE                 F           Salary            NaN
# 9         POLICE                 F           Salary            NaN
# 11        POLICE                 F           Salary            NaN
# 12        POLICE                 F           Salary            NaN
# ...          ...               ...              ...            ...
# 33177     POLICE                 F           Salary            NaN
# 33178     POLICE                 F           Salary            NaN
# 33179     POLICE                 F           Salary            NaN
# 33180     POLICE                 F           Salary            NaN
# 33181     POLICE                 F           Salary            NaN
#
#       Annual Salary
# 0            101442
# 1             94122
# 9             93354
# 11            84054
# 12            87006
# ...             ...
# 33177         72510
# 33178         72510
# 33179         48078
# 33180         90024
# 33181         93354
#
# [13414 rows x 7 columns]

# %%
x["Annual Salary"].plot.kde()

# %% [markdown]
# The distribution of salaries in the police department
